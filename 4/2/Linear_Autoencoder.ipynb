# %% [markdown]
# <a href="https://colab.research.google.com/github/shomerthesec/TensorFlow-Advanced-Techniques-Specialization/blob/main/4/2/Linear_Autoencoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ungraded Lab: First Autoencoder
#
# In this lab, you will build your first simple autoencoder. This will take in three-dimensional data, encodes it to two dimensions, and decodes it back to 3D.

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Prepare and preview the dataset
#
# You will first create a synthetic dataset to act as input to the autoencoder. You can do that with the function below.

# %%
def generate_data(m):
    '''plots m random points on a 3D plane'''

    angles = np.random.rand(m) * 3 * np.pi / 2 - 0.5
    data = np.empty((m, 3))
    data[:,0] = np.cos(angles) + np.sin(angles)/2 + 0.1 * np.random.randn(m)/2
    data[:,1] = np.sin(angles) * 0.7 + 0.1 * np.random.randn(m) / 2
    data[:,2] = data[:, 0] * 0.1 + data[:, 1] * 0.3 + 0.1 * np.random.randn(m)
    
    return data

# %%
# use the function above to generate data points
X_train = generate_data(100)
X_train = X_train - X_train.mean( axis=0, keepdims=True)

# preview the data
ax = plt.axes(projection='3d')
ax.scatter3D(X_train[:, 0], X_train[:, 1], X_train[:, 2], cmap='Reds');

# %% [markdown]
# ## Build the Model

# %% [markdown]
# Now you will build the simple encoder-decoder model. Notice the number of neurons in each Dense layer. The model will contract in the encoder then expand in the decoder.

# %%
encoder = keras.models.Sequential([keras.layers.Dense(2, input_shape=[3])]) # 3 in 2 out
decoder = keras.models.Sequential([keras.layers.Dense(3, input_shape=[2])]) # 2 in 3 out

autoencoder = keras.models.Sequential([encoder, decoder]) # sequential of 2 models is ok

# %% [markdown]
# ## Compile the Model

# %% [markdown]
# You can then setup the model for training.

# %%
autoencoder.compile(loss="mse", optimizer=keras.optimizers.SGD(lr=0.1))

# %% [markdown]
# ## Train the Model

# %% [markdown]
# You will configure the training to also use the input data as your target output. In our example, that will be `X_train`.

# %%
history = autoencoder.fit(X_train, X_train, epochs=200)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 2s 3ms/step - loss: 0.1785
# Epoch 2/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1168
# Epoch 3/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0826
# Epoch 4/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0704
# Epoch 5/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0622
# Epoch 6/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0550
# Epoch 7/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0530
# Epoch 8/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0499
# Epoch 9/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0488
# Epoch 10/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0427
# Epoch 11/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0454
# Epoch 12/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0419
# Epoch 13/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0438
# Epoch 14/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0381
# Epoch 15/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0380
# Epoch 16/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.
200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0055
# Epoch 73/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0055
# Epoch 74/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0056
# Epoch 75/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0054
# Epoch 76/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 77/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0050
# Epoch 78/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0053
# Epoch 79/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0051
# Epoch 80/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 81/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0051
# Epoch 82/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0048
# Epoch 83/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0051
# Epoch 84/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0049
# Epoch 85/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0051
# Epoch 86/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 87/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0049
# Epoch 88/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 89/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0046
# Epoch 90/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0045
# Epoch 91/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0047
# Epoch 92/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0050
# Epoch 93/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0048
# Epoch 94/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0050
# Epoch 95/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0043
# Epoch 96/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 97/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 98/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 99/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 100/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0047
# Epoch 101/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 102/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 103/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 104/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 105/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0044
# Epoch 106/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0043
# Epoch 107/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0044
# Epoch 108/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 109/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0044
# Epoch 110/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0049
# Epoch 111/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 112/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 113/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0045
# Epoch 114/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0044
# Epoch 115/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 116/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 117/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0046
# Epoch 118/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 119/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 120/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0045
# Epoch 121/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0046
# Epoch 122/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 123/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 124/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 125/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0047
# Epoch 126/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 127/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 128/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0043
# Epoch 129/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 130/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 131/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 132/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 133/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 134/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 135/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0044
# Epoch 136/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 137/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0043
# Epoch 138/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 139/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 140/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 141/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 142/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 143/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 144/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 145/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 146/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 147/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 148/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0036
# Epoch 149/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 150/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 151/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 152/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0043
# Epoch 153/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0043
# Epoch 154/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 155/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 156/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 157/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 158/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0037
# Epoch 159/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 160/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 161/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 162/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 163/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 164/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 165/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 166/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 167/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 168/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 169/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 170/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0037
# Epoch 171/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 172/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0037
# Epoch 173/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0037
# Epoch 174/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 175/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 176/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 177/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 178/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 179/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 180/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 181/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0037
# Epoch 182/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 183/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 184/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 185/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 186/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 187/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 188/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 189/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 190/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 191/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0037
# Epoch 192/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0043
# Epoch 193/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0037
# Epoch 194/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0040
# Epoch 195/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 196/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 197/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 198/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 199/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 200/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0039

# %% [markdown]
# ## Plot the encoder output

# %% [markdown]
# As mentioned, you can use the encoder to compress the input to two dimensions.

# %%
# encode the data
codings = encoder.predict(X_train)

# see a sample input-encoder output pair
print(f'input point: {X_train[0]}')
print(f'encoded point: {codings[0]}')
# Out:
# input point: [-0.3693915   0.37622799 -0.01195225]
# encoded point: [0.4831944  0.16746917]

# %%
# plot all encoder outputs
fig = plt.figure(figsize=(4,3))
plt.plot(codings[:,0], codings[:, 1], "b.") # as codings has 2 dims [0x1]
plt.xlabel("$z_1$", fontsize=18)
plt.ylabel("$z_2$", fontsize=18, rotation=0)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Plot the Decoder output

# %% [markdown]
# The decoder then tries to reconstruct the original input. See the outputs below. You will see that although not perfect, it still follows the general shape of the original input.

# %%
# decode the encoder output
decodings = decoder.predict(codings)

# see a sample output for a single point
print(f'input point: {X_train[0]}')
print(f'encoded point: {codings[0]}')
print(f'decoded point: {decodings[0]}')
# Out:
# input point: [-0.3693915   0.37622799 -0.01195225]
# encoded point: [0.4831944  0.16746917]
# decoded point: [-0.31864715  0.33594313  0.09850702]

# %%
# plot the decoder output
ax = plt.axes(projection='3d')
ax.scatter3D(decodings[:, 0], decodings[:, 1], decodings[:, 2], c=decodings[:, 0], cmap='Reds');

# %% [markdown]
# That's it for this simple demonstration of the autoencoder!
